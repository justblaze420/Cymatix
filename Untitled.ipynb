# %%
# !pipx install numpy
# Out:
# ⚠️  Note: f2py was already on your PATH at /usr/bin/f2py
# ⚠️  Note: numpy-config was already on your PATH at /usr/bin/numpy-config
#   installed package numpy 2.3.1, installed using Python 3.13.3
#   These apps are now globally available
#     - f2py
#     - numpy-config
# ⚠️  Note: '/home/blazex/.local/bin' is not on your PATH environment variable.
#     These apps will not be globally accessible until your PATH is updated. Run
#     `pipx ensurepath` to automatically add it, or manually modify your PATH in
#     your shell's config file (e.g. ~/.bashrc).
# done! ✨ 🌟 ✨

# %%
# !pipx install matplotlib
# Out:
# ⣽ installing matplotlibronment

# %%
# !python cymatix.py
# Out:
# Traceback (most recent call last):
#   File "/home/blazex/Bassssh/Cymatix/cymatix.py", line 2, in <module>
#     import matplotlib.pyplot as plt
# ModuleNotFoundError: No module named 'matplotlib'
